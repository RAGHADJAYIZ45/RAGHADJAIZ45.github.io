# %%
words = []

for i in range(5):
    word = input("Enter a word: ")
    words.append(word)

words_tuple = tuple(words)

print("First word:", words_tuple[0])
print("Last word:", words_tuple[-1])
print("Total number of words:", len(words_tuple))

search_word = input("Enter a word to search: ")

if search_word in words_tuple:
    print("Word found in tuple")
else:
    print("Word not found in tuple")
# Out:
# Enter a word:  raghad
# Enter a word:  jayiz
# Enter a word:  muhammed
# Enter a word:  Alrasheed
# Enter a word:  Alfaqiri
# First word: raghad
# Last word: Alfaqiri
# Total number of words: 5
# Enter a word to search:  name
# Word not found in tuple

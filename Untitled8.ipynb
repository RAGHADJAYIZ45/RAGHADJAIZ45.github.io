# %%
#Askk the user to enternthe score
score=float(input("Enter the student score:"))
#check if the student passed or failed
if score >=50:
    print("Status:passed")
else:
    print("astus:Failed")
#Assign grade using if/elif/else
if score>=90:
    grade="A"
elif score>=80:
    grade="B"
elif score >=70:
    grade="C"
elif scoro>=60:
    grade="D"
else:
    grade="F"
print("Grade:",grade)
#Display message using match
match grade:
 cae"A":
  print("Excellent Work")
 case"B"
  print("very good job!")
 case"C"
  print("good effort!")
 case"D"
  print("You passed,but try harder.")
 case"F"
  print("You failed.Dont give up!")
 case_:
  print("Invalid grade")
# Out:
#   Cell In[2], line 22
#     cae"A":
#     ^
# SyntaxError: invalid syntax

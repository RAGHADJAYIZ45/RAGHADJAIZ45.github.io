# %%
#Display menu
print ("Menu:")
print ("1.Addition")
print ("2.Subtraction")
print ("3.Multiplication")
print ("4.Divsion")
choice=input("enter choose number")
num1=float(input("enter first number"))
num2=float(input("enter seond number"))
#Ask user to choose an option
choice = input ("Choose an option(1-4):")
#perform operation using match
match choice:
    case"1":
     result=num1 + num2
     print("Result:",result)
    case"2":
     result= num1 - num2
     print("Result:",result)
    case"3":
     result = num1*num2 
     print("Result:",result)
    case"4":
     if num2!=0:
        result=num1/num2
        print("Result:",result)
     else:
      print("Error:Cannot divide by zero")
         
    case _:
     print ("Invalid choice")
# Out:
# Menu:
# 1.Addition
# 2.Subtraction
# 3.Multiplication
# 4.Divsion
# enter choose number 1
# enter first number 2
# enter seond number 3
# Choose an option(1-4): 4
# Result: 0.6666666666666666

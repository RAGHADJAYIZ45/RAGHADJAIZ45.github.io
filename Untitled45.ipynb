# %%
num = int(input("Enter a number: "))

for i in range(1, 13):
    result = num * i

    if result % 3 == 0:
        continue

    if result > 50:
        break

    print(num, "x", i, "=", result)
# Out:
# Enter a number:  13
# 13 x 1 = 13
# 13 x 2 = 26

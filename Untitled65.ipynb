# %%
names = []

for i in range(5):
    name = input("Enter a name: ")
    names.append(name)

names_tuple = tuple(names)
print("Tuple:", names_tuple)

name_dict = {name: len(name) for name in names}
print("Dictionary:", name_dict)

length_set = set(name_dict.values())
print("Set of unique name lengths:", length_set)
# Out:
# Enter a name:  Raghad
# Enter a name:  layal
# Enter a name:  Noor
# Enter a name:  Sara
# Enter a name:  Lana
# Tuple: ('Raghad', 'layal', 'Noor', 'Sara', 'Lana')
# Dictionary: {'Raghad': 6, 'layal': 5, 'Noor': 4, 'Sara': 4, 'Lana': 4}
# Set of unique name lengths: {4, 5, 6}

# %%
color = input("Enter a color(red,yellow,green):").lower().strip()
#Cheek if input is not empty
if color=="":
    print("No collor entered!")
else:
    #Use match-case to decide the action
    match color:
        case "red":
            print("Stop")
        case "yellow":
            print ("Get Ready")
        case "green":
            print ("Go")
        case _:
            print("invalid color")
# Out:
# Enter a color(red,yellow,green): red
# Stop

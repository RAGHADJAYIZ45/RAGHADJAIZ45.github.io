# %%
number =int(input("Enter a number:"))
#raghad
if number %2==0:
    print("positive")
else: 
    print("Not Positive")
#451005003
if number>=10 and number <=50:
    print ("The number is between 10 and 50")
else:
    print
# Out:
# Enter a number: 55
# Not Positive
